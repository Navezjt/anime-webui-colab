# %% [markdown]
# ---
# # **(JCTN)**

# %%
# @title RADIO JOEL CTN
# %%html
<b>Press play on the music player(Uses only 13MB of data)</b><br/>
<audio src="http://stream.zeno.fm/vq4s9m2sg48uv" controls>
# Out:
# <b>Press play on the music player(Uses only 13MB of data)</b><br/>
# <audio src="http://stream.zeno.fm/vq4s9m2sg48uv" controls>

# %%
#@title 🚀 `Launch web UI`

#@markdown ### ⭐ Model selection <sup>[**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Selecting-a-model)</sup>
#@markdown <small> It could take 4-7 minutes to see a link to the web UI, please be patient! :) </small>
model = "1.5 beta 3 illusion" #@param ["1.3", "1.3.5", "1.4 epoch 1", "1.4 epoch 2", "1.5 beta 1", "1.5 beta 2", "1.5 beta 2 aesthetic", "1.5 beta 3 base", "1.5 beta 3 illusion", "1.5 beta 3 ink", "1.5 beta 3 mofu", "1.5 beta 3 radiance"]

#@markdown <small> Select ControlNet models to use [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Selecting-ControlNet-models) </small>
controlnet = "t2i" #@param ['none','v1.0','v1.0-diff','t2i','v1.1']
#@markdown ### 🔧 Web UI settings
#@markdown <small> This option only affects the **first** launch [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/First-launch-web-UI-settings) </small>
webui_version = "stable" #@param ["fallback","stable","latest","latest-dev","ui-redesign"]
extensions_version = "stable" #@param ["none","lite","stable","latest","experimental"]
#@markdown <small> This saves your generation to Google Drive [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Saving-outputs-to-Google-Drive) </small>
outputs_to_drive = False #@param {type:'boolean'}
output_drive_folder = "AI/Generated" #@param {type:'string'}
#@markdown <small> Change tunnels if you have connection issues with `gradio` [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Using-different-tunnels) </small>
tunnel = "cloudflared" #@param ['gradio', 'ngrok', 'cloudflared', 'localhostrun', 'remotemoe']
ngrok_token = "" #@param { type:'string' }
ngrok_region = "auto" #@param ["auto", "ap", "au", "eu", "in", "jp", "sa", "us"]

ui_config_dictionaries = {
  "1.3": {
    "txt2img/Prompt/value": "",
    "txt2img/Negative prompt/value": ""
  },
  "1.4": {
    "txt2img/Prompt/value": "masterpiece, best quality, high quality, absurdres, ",
    "txt2img/Negative prompt/value": "worst quality, low quality, medium quality, deleted, lowres, comic, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, jpeg artifacts, signature, watermark, username, blurry"
  },
  "1.5": {
    "txt2img/Prompt/value": "\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)",
    "txt2img/Negative prompt/value": "lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)",
    "txt2img/Sampling method/value": "DPM++ 2M Karras",
    "txt2img/Sampling steps/value": 20,
    "txt2img/CFG Scale/value": 7,
    "txt2img/Denoising strength/value": 0.6,
  }
}

config_dictionary = {
  "CLIP_stop_at_last_layers": 1
}

model_dictionary = {
  "1.3":"https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt",
  "1.3.5":"https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/models/wd-1-3-5_80000-fp32.ckpt",
  "1.4 epoch 1":"https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e1.ckpt",
  "1.4 epoch 2":"https://huggingface.co/saltacc/wd-1-4-anime/resolve/main/wd-1-4-epoch2-fp16.safetensors",
  "1.5 beta 1": "https://huggingface.co/waifu-diffusion/wd-1-5-beta/resolve/main/checkpoints/wd15-beta1-fp16.safetensors",
  "1.5 beta 2": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-fp16.safetensors",
  "1.5 beta 2 aesthetic": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.safetensors",
  "1.5 beta 3 base": "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-beta3-base-fp16.safetensors",
  "1.5 beta 3 illusion": "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-illusion-fp16.safetensors",
  "1.5 beta 3 ink": "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-ink-fp16.safetensors",
  "1.5 beta 3 mofu": "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-mofu-fp16.safetensors",
  "1.5 beta 3 radiance": "https://huggingface.co/waifu-diffusion/wd-1-5-beta3/resolve/main/wd-radiance-fp16.safetensors",
}

model_yaml_dictionary = {
  "1.4 epoch 1":"https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e1.yaml",
  "1.4 epoch 2":"https://huggingface.co/saltacc/wd-1-4-anime/resolve/main/wd-1-4-epoch2-fp16.yaml",
  "1.5 beta 1": "https://huggingface.co/waifu-diffusion/wd-1-5-beta/resolve/main/checkpoints/wd15-beta1-fp16.yaml",
  "1.5 beta 2": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-fp16.yaml",
  "1.5 beta 2 aesthetic": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp16.yaml",
}

vae_link = "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime2.ckpt"
vae_name = vae_link.split("/")[-1]

model_link = model_dictionary[model]
model_name = model_link.split("/")[-1]

yaml_link = model_yaml_dictionary.get(model, '')

git_flags = "-q"
wget_flags = "-q --show-progress"

try:
  utility
except NameError:
  # !wget -q https://github.com/Navezjt/anime-webui-colab/raw/main/configs/utility.py -P /content/
  import utility
  utility.log_usage("notebook-waifu_diffusion")

utility.mount_drive(outputs_to_drive)

if not utility.has_run:

  for command in utility.colab_memory_fix():
    # !{command}
  # %env LD_PRELOAD=libtcmalloc.so
  # !rm *.deb

  # !{utility.install_webui(webui_version)}

  for extension_link in utility.extensions_list(extensions_version,webui_version,controlnet):
    extension_name = extension_link.split('/')[-1]
    print(f'  └ {extension_name}')
    # !git clone {git_flags} {extension_link}
  # !git clone {git_flags} github.com/username/<repo> {extensions_folder}/<repo>

  for config_file in utility.configs_list():
    # !wget -q {config_file} -P {utility.web_ui_folder}/

  for embedding in utility.embeddings_list():
    # !wget -q {embedding} -P {utility.embeddings_folder}/
  # !wget {wget_flags} site.com/embedding.pt -P {utility.embeddings_folder}/

  utility.dictionary_to_json(f"{utility.web_ui_folder}/config.json", config_dictionary)

  for patch in utility.patch_list():
    # !{patch}

  utility.has_run = True

utility.output_to_gdrive(outputs_to_drive, output_drive_folder)

# !{utility.download_model(model_link,yaml_link)}
# !{utility.download_vae(vae_link)}

utility.dictionary_to_json(f"{utility.web_ui_folder}/ui-config.json", ui_config_dictionaries[model[:3]])

arg_list = utility.arguments(
  model=f"{utility.models_folder}/{model_name}",
  vae=f"{utility.vae_folder}/{vae_name}",
  tunnel=tunnel,
  ng_token=ngrok_token,
  ng_region=ngrok_region,
)

for controlnet_model_link in utility.controlnet_list(controlnet,webui_version,extensions_version):
  # !{utility.download_controlnet(controlnet_model_link)}

# %cd {utility.web_ui_folder}

args = " ".join(arg_list)
# !python launch.py {args}
#@markdown <i><small> Did something break? Please report it on [Github](https://github.com/NUROISEA/anime-webui-colab/issues) or fill out this [Google Form](https://forms.gle/dnaJojPR4yqvr9dN8) (no sign-in needed)!
# Out:
# 👍 Utility script imported.
# 🩹 Applying Colab memory fix...
# env: LD_PRELOAD=libtcmalloc.so
# 🌟 Installing stable-diffusion-webui...
# 💃 ControlNet t2i models detected, including related extensions!
# 📦 Installing 15 extensions...
#   └ 2d-openpose-editor
#   └ 3d-openpose-editor
#   └ aspect-ratio-preset
#   └ batchlinks
#   └ controlnet
#   └ cutoff
#   └ dynamic-thresholding
#   └ images-browser
#   └ latent-couple-two-shot
#   └ session-organizer
#   └ state
#   └ tagcomplete
#   └ tiled-multidiffusion-upscaler
#   └ tokenizer
#   └ tunnels
# 🔧 Fetching configs...
# 💉 Fetching embeddings...
# 🩹 Applying web UI Colab patches...
# 📦 Installing aria2...
# ⏬ Downloading wd-illusion-fp16.safetensors to /content/stable-diffusion-webui/models/Stable-diffusion...
# ⏬ Downloading kl-f8-anime2.ckpt to /content/stable-diffusion-webui/models/VAE...
# ⌛ This might take a while! Grab a 🍿 or something xD
#
# 📢 These models are FP16, btw. ;)
#
# 🤙 Downloading 8 ControlNet t2i files/models...
# ⏬ Downloading t2iadapter_canny.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_color.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_depth.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_keypose.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_openpose.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_seg.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_sketch.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# ⏬ Downloading t2iadapter_style.safetensors to /content/stable-diffusion-webui/extensions/controlnet/models...
# /content/stable-diffusion-webui
# fatal: No names found, cannot describe anything.
# Python 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
# Version: ## 1.4.0
# Commit hash: 394ffa7b0a7fff3ec484bcd084e673a8b301ccc8
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai...
# Cloning K-diffusion into /content/stable-diffusion-webui/repositories/k-diffusion...
# Cloning CodeFormer into /content/stable-diffusion-webui/repositories/CodeFormer...
# Cloning BLIP into /content/stable-diffusion-webui/repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements
# Downloading pose_landmark_full.tflite...
# Downloading pose_web.binarypb...
# Downloading pose_solution_packed_assets.data...
# Downloading pose_solution_simd_wasm_bin.wasm...
# Downloading pose_solution_packed_assets_loader.js...
# Downloading pose_solution_simd_wasm_bin.js...
#
#
# Installing pycloudflared
#
# Installing ImageReward requirement for image browser
#
# Installing sd-webui-controlnet requirement: mediapipe
# Installing sd-webui-controlnet requirement: svglib
# Installing sd-webui-controlnet requirement: fvcore
#
# Launching Web UI with arguments: --opt-sdp-attention --lowram --no-hashing --enable-insecure-extension-access --no-half-vae --disable-safe-unpickle --gradio-queue --ckpt /content/stable-diffusion-webui/models/Stable-diffusion/wd-illusion-fp16.safetensors --vae-path /content/stable-diffusion-webui/models/VAE/kl-f8-anime2.ckpt --cloudflared
# No module 'xformers'. Proceeding without it.
# 2023-07-19 16:37:34,742 - ControlNet - INFO - ControlNet v1.1.233
# ControlNet preprocessor location: /content/stable-diffusion-webui/extensions/controlnet/annotator/downloads
# 2023-07-19 16:37:35,031 - ControlNet - INFO - ControlNet v1.1.233
# Image Browser: ImageReward is not installed, cannot be used.
# Image Browser: Creating database
# Image Browser: Database created
# cloudflared detected, trying to connect...
# Download cloudflared...: 100% 34.8M/34.8M [00:00<00:00, 292MB/s]
# Loading weights [None] from /content/stable-diffusion-webui/models/Stable-diffusion/wd-illusion-fp16.safetensors
# Running on local URL:  http://127.0.0.1:7860
# Public WebUI Colab URL: https://propose-seen-entertaining-robinson.trycloudflare.com
# Startup time: 16.3s (import torch: 4.8s, import gradio: 0.7s, import ldm: 0.5s, other imports: 2.1s, setup codeformer: 0.3s, load scripts: 6.1s, create ui: 1.5s, gradio launch: 0.3s).
# preload_extensions_git_metadata for 22 extensions took 0.67s
# Creating model from config: /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai/configs/stable-diffusion/v2-inference-v.yaml
# LatentDiffusion: Running in v-prediction mode
# DiffusionWrapper has 865.91 M params.
# Loading VAE weights from commandline argument: /content/stable-diffusion-webui/models/VAE/kl-f8-anime2.ckpt
# Applying attention optimization: sdp... done.
# Textual inversion embeddings loaded(0):
# Textual inversion embeddings skipped(7): bad-hands-5, bad-artist, EasyNegative, EasyNegativeV2, bad-artist-anime, bad_prompt_version2, bad-image-v2-39000
# Model loaded in 48.3s (load weights from disk: 29.3s, find config: 7.7s, load config: 0.4s, create model: 0.4s, apply weights to model: 2.6s, apply half(): 3.0s, load VAE: 2.7s, move model to device: 1.6s, calculate empty prompt: 0.4s).
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:01<00:33,  1.78s/it]
#  15% 3/20 [00:02<00:08,  1.92it/s]
#  20% 4/20 [00:02<00:06,  2.65it/s]
#  25% 5/20 [00:02<00:04,  3.36it/s]
#  30% 6/20 [00:02<00:03,  3.99it/s]
#  35% 7/20 [00:02<00:02,  4.42it/s]
#  40% 8/20 [00:02<00:02,  4.49it/s]
#  45% 9/20 [00:03<00:02,  4.94it/s]
#  50% 10/20 [00:03<00:01,  5.27it/s]
#  55% 11/20 [00:03<00:01,  5.55it/s]
#  60% 12/20 [00:03<00:01,  5.74it/s]
#  65% 13/20 [00:03<00:01,  5.90it/s]
#  70% 14/20 [00:03<00:00,  6.00it/s]
#  75% 15/20 [00:04<00:00,  6.11it/s]
#  80% 16/20 [00:04<00:00,  6.07it/s]
#  85% 17/20 [00:04<00:00,  6.14it/s]
#  90% 18/20 [00:04<00:00,  6.15it/s]
#  95% 19/20 [00:04<00:00,  6.19it/s]
# 100% 20/20 [00:04<00:00,  4.10it/s]
#
# Total progress: 100% 20/20 [00:10<00:00,  1.90it/s]
# {"prompt": "\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)", "all_prompts": ["\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)"], "negative_prompt": "lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)", "all_negative_prompts": ["lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)"], "seed": 321413425, "all_seeds": [321413425], "subseed": 179979664, "all_subseeds": [179979664], "subseed_strength": 0, "width": 512, "height": 512, "sampler_name": "DPM++ 2M Karras", "cfg_scale": 7, "steps": 20, "batch_size": 1, "restore_faces": false, "face_restoration_model": null, "sd_model_hash": null, "seed_resize_from_w": 0, "seed_resize_from_h": 0, "denoising_strength": null, "extra_generation_params": {}, "index_of_first_image": 0, "infotexts": ["(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)\nNegative prompt: lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)\nSteps: 20, Sampler: DPM++ 2M Karras, CFG scale: 7, Seed: 321413425, Size: 512x512, Model: wd-illusion-fp16, RNG: CPU, Version: ## 1.4.0"], "styles": [], "job_timestamp": "20230719164734", "clip_skip": 1, "is_using_inpainting_conditioning": false}
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:04,  4.44it/s]
#  15% 3/20 [00:00<00:02,  5.72it/s]
#  20% 4/20 [00:00<00:02,  5.75it/s]
#  25% 5/20 [00:00<00:02,  5.94it/s]
#  30% 6/20 [00:01<00:02,  6.02it/s]
#  35% 7/20 [00:01<00:02,  6.08it/s]
#  40% 8/20 [00:01<00:01,  6.13it/s]
#  45% 9/20 [00:01<00:01,  6.11it/s]
#  50% 10/20 [00:01<00:01,  6.08it/s]
#  55% 11/20 [00:01<00:01,  6.07it/s]
#  60% 12/20 [00:02<00:01,  5.96it/s]
#  65% 13/20 [00:02<00:01,  5.97it/s]
#  70% 14/20 [00:02<00:01,  5.89it/s]
#  75% 15/20 [00:02<00:00,  5.83it/s]
#  80% 16/20 [00:02<00:00,  5.66it/s]
#  85% 17/20 [00:02<00:00,  5.70it/s]
#  90% 18/20 [00:03<00:00,  5.72it/s]
#  95% 19/20 [00:03<00:00,  5.77it/s]
# 100% 20/20 [00:03<00:00,  5.84it/s]
#
# Total progress: 100% 20/20 [00:03<00:00,  5.26it/s]
# {"prompt": "\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)", "all_prompts": ["\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)"], "negative_prompt": "lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)", "all_negative_prompts": ["lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)"], "seed": 1440909575, "all_seeds": [1440909575], "subseed": 1499648140, "all_subseeds": [1499648140], "subseed_strength": 0, "width": 512, "height": 512, "sampler_name": "DPM++ 2M Karras", "cfg_scale": 7, "steps": 20, "batch_size": 1, "restore_faces": false, "face_restoration_model": null, "sd_model_hash": null, "seed_resize_from_w": 0, "seed_resize_from_h": 0, "denoising_strength": null, "extra_generation_params": {}, "index_of_first_image": 0, "infotexts": ["(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)\nNegative prompt: lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)\nSteps: 20, Sampler: DPM++ 2M Karras, CFG scale: 7, Seed: 1440909575, Size: 512x512, Model: wd-illusion-fp16, RNG: CPU, Version: ## 1.4.0"], "styles": [], "job_timestamp": "20230719164954", "clip_skip": 1, "is_using_inpainting_conditioning": false}
#   0% 0/20 [00:00<?, ?it/s]
#   5% 1/20 [00:00<00:04,  4.20it/s]
#  15% 3/20 [00:00<00:03,  5.60it/s]
#  20% 4/20 [00:00<00:02,  5.82it/s]
#  25% 5/20 [00:00<00:02,  5.94it/s]
#  30% 6/20 [00:01<00:02,  5.91it/s]
#  35% 7/20 [00:01<00:02,  6.03it/s]
#  40% 8/20 [00:01<00:01,  6.08it/s]
#  45% 9/20 [00:01<00:01,  6.11it/s]
#  50% 10/20 [00:01<00:01,  6.18it/s]
#  55% 11/20 [00:01<00:01,  6.17it/s]
#  60% 12/20 [00:02<00:01,  6.12it/s]
#  65% 13/20 [00:02<00:01,  6.15it/s]
#  70% 14/20 [00:02<00:00,  6.13it/s]
#  75% 15/20 [00:02<00:00,  6.15it/s]
#  80% 16/20 [00:02<00:00,  6.17it/s]
#  85% 17/20 [00:02<00:00,  6.14it/s]
#  90% 18/20 [00:03<00:00,  6.03it/s]
#  95% 19/20 [00:03<00:00,  6.06it/s]
# 100% 20/20 [00:03<00:00,  5.97it/s]
#
# Total progress: 100% 20/20 [00:03<00:00,  5.38it/s]
# {"prompt": "\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)", "all_prompts": ["\n\n(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)"], "negative_prompt": "lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)", "all_negative_prompts": ["lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)"], "seed": 1190278432, "all_seeds": [1190278432], "subseed": 2300901642, "all_subseeds": [2300901642], "subseed_strength": 0, "width": 512, "height": 512, "sampler_name": "DPM++ 2M Karras", "cfg_scale": 7, "steps": 20, "batch_size": 1, "restore_faces": false, "face_restoration_model": null, "sd_model_hash": null, "seed_resize_from_w": 0, "seed_resize_from_h": 0, "denoising_strength": null, "extra_generation_params": {}, "index_of_first_image": 0, "infotexts": ["(exceptional, best aesthetic, new, newest, best quality, masterpiece, extremely detailed, anime, waifu:1.2)\nNegative prompt: lowres, ((bad anatomy)), ((bad hands)), text, missing finger, extra digits, fewer digits, blurry, ((mutated hands and fingers)), (poorly drawn face), ((mutation)), ((deformed face)), (ugly), ((bad proportions)), ((extra limbs)), extra face, (double head), (extra head), ((extra feet)), monster, logo, cropped, worst quality, jpeg, humpbacked, long body, long neck, ((jpeg artifacts)), deleted, old, oldest, ((censored)), ((bad aesthetic)), (mosaic censoring, bar censor, blur censor)\nSteps: 20, Sampler: DPM++ 2M Karras, CFG scale: 7, Seed: 1190278432, Size: 512x512, Model: wd-illusion-fp16, RNG: CPU, Version: ## 1.4.0"], "styles": [], "job_timestamp": "20230719165342", "clip_skip": 1, "is_using_inpainting_conditioning": false}

# %%
#@title 📱 `Colab Mobile Keep Alive`
#@markdown <small> Run this cell (before running 🚀 `Launch web UI`) to keep the tab alive in mobile [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Keeping-colab-tab-alive-in-mobile) </small>

# %%html
<b>Press play on the music player to keep the tab alive before running the start cell (Uses only 13MB of data)</b><br/>
<audio src="https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a" controls>

# %%
#@title 💾 `Saving images`

#@markdown <small>The zip file will be visible at the files tab.</small>
from datetime import datetime
str_date = datetime.today().strftime('%Y-%m-%d-%H%M%S')
archive_name = f"outputs-{str_date}.zip"

# %cd {utility.web_ui_folder}
print("Zipping...")
# !zip -qr /content/{archive_name} outputs
print(f"\033[92mZipped. You can now find {archive_name} at the files tab.\033[0m")

# ----

#@markdown <small>This copies the zip file to your Google Drive</small>
copy_to_gdrive = False #@param {type:'boolean'}
gdrive_folder = "AI/Generated" #@param { 'type': 'string' }

if copy_to_gdrive:
  utility.log_usage('zip-to-gdrive')
  from google.colab import drive

  print("Mounting to Google Drive...")
  drive.mount('/content/drive')
  if gdrive_folder == "":
    gdrive_folder = "AI/Generated"

  drive_folder = f"/content/drive/MyDrive/{gdrive_folder}"

  # !mkdir -p {drive_folder}
  # !cp /content/{archive_name} {drive_folder}
  print(f"\033[92mCopied to {gdrive_folder}!\033[0m")
#@markdown <small>Upload the zip file to a temporary file hosting [**[?]**](https://github.com/NUROISEA/anime-webui-colab/wiki/Uploading-to-temporary-file-hosts)</small>
upload_to_temp = False #@param {type:'boolean'}
temp_file_host = "transfer.sh" #@param ["bashupload.com", "keep.sh", "temp.sh", "transfer.sh"]

host_dictionary = {
  "bashupload.com": "https://bashupload.com",
  "keep.sh": "https://free.keep.sh",
  "temp.sh": "https://temp.sh",
  "transfer.sh": f"https://transfer.sh/{archive_name}",
}
host_link = host_dictionary[temp_file_host] # not sure if colab can do this directly at {}

if upload_to_temp:
  utility.log_usage('zip-to-temp-host')
  utility.log_usage(f'zip-temp-host-{temp_file_host}')
  print(f"Uploading to {temp_file_host}...")
  # !curl -T /content/{archive_name} {host_link}
  print("\n\033[92m^^^ This is your download link! ^^^\033[0m")
#@markdown <small>Delete colab outputs (the saved zip is unaffected)</small>
delete_local_files = False #@param {type:'boolean'}
if delete_local_files:
  utility.log_usage('local-delete-outputs')
  # %cd {utility.web_ui_folder}
  # !rm -rf outputs
  print("\033[91mDeleted the outputs folder.\033[0m")

# %% [markdown]
# ---
# # **Useful Utilities (JCTN)**

# %% [markdown]
# <h2>🌟 <code>Waifu Diffusion Colab</code></h2>
#
# - 📚 [Anime Web UI Colab Wiki](https://github.com/NUROISEA/anime-webui-colab/wiki)
# - 🤔 [How to use](https://github.com/NUROISEA/anime-webui-colab/wiki/Getting-started)
# - 🤗 [HuggingFace Repo (<1.5)](https://huggingface.co/hakurei/waifu-diffusion)
# - 🤗 [HuggingFace Repo (1.5 beta 1)](https://huggingface.co/waifu-diffusion/wd-1-5-beta)
# - 🤗 [HuggingFace Repo (1.5 beta 2)](https://huggingface.co/waifu-diffusion/wd-1-5-beta2)
# - 🤗 [HuggingFace Repo (1.5 beta 3)](https://huggingface.co/waifu-diffusion/wd-1-5-beta3)
#
# ----
# # `**🤗JCTN**`
